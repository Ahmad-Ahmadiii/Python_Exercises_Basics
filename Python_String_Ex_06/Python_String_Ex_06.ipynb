# %% [markdown]
# ## (Python Tutorial)
# #### from (Python  for  everybody books) by Prof Charles Severance
# #### (coding by: Ahmad Ahmadi)
# ___
# ___

# %% [markdown]
# ### Exercise 6:
# #### Level : <span style='color:green'> Basic </span>
#  1)  Write a program to read through the **mbox-short.txt** and figure out who has sent the **greatest number of mail messages.** The program looks for 'From ' lines and takes the second word of those lines as the person who sent the mail. The program creates a **Python dictionary** that maps the sender's mail address to a count of the number of times they appear in the file. After the dictionary is produced, the program reads through the dictionary using a maximum loop to find the most prolific committer.
#
#  |Format:|
#  |:--|
#  |From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008|
#
# ___
# #### <span style='color:red'>Hint :</span>
#
# * make sure **not to include the lines that start with 'From:'.** Also look at the last line of the sample output to see how to print the count.
# * **open():** open(file name, mode='r') -- make a handle to that specific file.
# * here file name.txt = words.txt
# * mode = 'r' means open a file for reading.
# * mode = 'w' means open a file for writing.
# * mode = 'a' means open a file for appending.
# * **string.split():** split(seperator, maxsplit) -- returns a list of splitted word.
# * **dictionary.get():** get() -- returns value of specified key in dictionary.
# * there are **two** ways of defining an **(Empty dictionary or list)** in python:
#
# | **List / dictionary**  | **one way:**|**second way:**|
# |-----|-----|-----|
# |**list**| **list_name = [ ]**| **list_name = list()**|
# |**dictoinary**|**dict_name = { }**| **dict_name = dict()**|
#
#
#
# ___

# %%
# open file (mbox-short.txt), and read through each line.
file_name = input('Enter a file name: ')
file_name = file_name + '.txt'
# try & except block:
try:
    file_handle = open(file_name, 'r')
except:
    print('invalid file name!')
    
# making code neat (optional you can remove it.)
print(' ') 
# printing 10 lines, inside of the file:
for indx, line in enumerate(file_handle):
    print(line)
    print('=====================')
    if indx == 10:
        break
# Out:
# Enter a file name: mbox_short
#
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# =====================
# Return-Path: <postmaster@collab.sakaiproject.org>
#
# =====================
# Received: from murder (mail.umich.edu [141.211.14.90])
#
# =====================
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# =====================
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# =====================
# X-Sieve: CMU Sieve 2.3
#
# =====================
# Received: from murder ([unix socket])
#
# =====================
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# =====================
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# =====================
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# =====================
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# =====================

# %%
# open file (mbox-short.txt), and read through each line.
file_name = input('Enter a file name: ')
file_name = file_name + '.txt'
# try & except block:
try:
    file_handle = open(file_name, 'r')
except:
    print('invalid file name!')
    
# making code neat (optional you can remove it.):
print() 
# for loops to iterate through each line:
for line in file_handle:
    # extract line which starts with ('From '):
    if line.startswith('From '):
        # split extracted line to its words.
        email_address = line.split()
        # extracting email address by using email_address[1]
        email_address = email_address[1]
        # printing results:
        print('Email Adress: ', email_address)
# Out:
# Enter a file name: mbox_short
#
# Email Adress:  stephen.marquard@uct.ac.za
# Email Adress:  louis@media.berkeley.edu
# Email Adress:  zqian@umich.edu
# Email Adress:  rjlowe@iupui.edu
# Email Adress:  zqian@umich.edu
# Email Adress:  rjlowe@iupui.edu
# Email Adress:  cwen@iupui.edu
# Email Adress:  cwen@iupui.edu
# Email Adress:  gsilver@umich.edu
# Email Adress:  gsilver@umich.edu
# Email Adress:  zqian@umich.edu
# Email Adress:  gsilver@umich.edu
# Email Adress:  wagnermr@iupui.edu
# Email Adress:  zqian@umich.edu
# Email Adress:  antranig@caret.cam.ac.uk
# Email Adress:  gopal.ramasammycook@gmail.com
# Email Adress:  david.horwitz@uct.ac.za
# Email Adress:  david.horwitz@uct.ac.za
# Email Adress:  david.horwitz@uct.ac.za
# Email Adress:  david.horwitz@uct.ac.za
# Email Adress:  stephen.marquard@uct.ac.za
# Email Adress:  louis@media.berkeley.edu
# Email Adress:  louis@media.berkeley.edu
# Email Adress:  ray@media.berkeley.edu
# Email Adress:  cwen@iupui.edu
# Email Adress:  cwen@iupui.edu
# Email Adress:  cwen@iupui.edu

# %%
# open file (mbox-short.txt), and read through each line. 
file_name = input('Enter a file name: ')
file_name = file_name + '.txt'
# try & except block:
try:
    file_handle = open(file_name, 'r')
except:
    print('invalid file name!')
    
# making code neat (optional you can remove it.)
print() 
# initialize email_counts with zero value:
emails_dict = {}
emails_list = []
# for loops to iterate through each line:
for line in file_handle:
     # extract line which starts with ('From'):
    if line.startswith('From '):
        email_address = line.split()
        # extracting email address by using email_address[1]
        email_address = email_address[1]
        emails_list.append(email_address)
# for loops to iterate through each email address in emails_list:
for email_address in emails_list:
    # using get() method to find the most occurence of an key dictionary:
    emails_dict[email_address] = emails_dict.get(email_address, 0) + 1
    
# similar to previous Exercise to find the max / min value
max_count =None
min_count = None
# using items() dictionary method to get (key, value) pair.
for key, value in emails_dict.items():
    if max_count is None:
        max_count = value
    elif value > max_count:
        max_name = key
        name = value
        max_count = value
    if min_count is None:
        min_name = key
        min_count = value
    elif value < min_count:
        min_count = value
        
# printing results:
print('max email is for', '(', max_name,')', 'and the number is ', '(', max_count,')')
print('min email is for', '(', min_name,')', 'and the number is ', '(', min_count,')')
# Out:
# Enter a file name: mbox_short
#
# max email is for ( cwen@iupui.edu ) and the number is  ( 5 )
# min email is for ( stephen.marquard@uct.ac.za ) and the number is  ( 1 )
